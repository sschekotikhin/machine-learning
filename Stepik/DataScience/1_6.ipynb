# %%
import pandas as pd
import numpy as np

# %%
sp_df = pd.read_csv('StudentsPerformance.csv')
sp_df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
mean_scores = sp_df.groupby(['gender', 'lunch']) \
                   .aggregate({'math score': 'mean', 'reading score': 'mean'}) \
                   .rename(columns={'math score': 'mean_math_score', 'reading score': 'mean_reading_score'})

# %%
mean_scores
# Out:
#                      mean_math_score  mean_reading_score
# gender lunch
# female free/reduced        55.814815           67.386243
#        standard            68.124620           75.607903
# male   free/reduced        62.457831           61.542169
#        standard            72.022152           67.537975

# %%
mean_scores.loc[[('female', 'standard'), ('female', 'free/reduced')]] # многоуровневые индексы
# Out:
#                      mean_math_score  mean_reading_score
# gender lunch
# female standard            68.124620           75.607903
#        free/reduced        55.814815           67.386243

# %%
sp_df.groupby(['gender']).lunch.unique()
# Out:
# gender
# female    [standard, free/reduced]
# male      [free/reduced, standard]
# Name: lunch, dtype: object

# %%
sp_df.sort_values(['gender', 'math score'], ascending=False).groupby('gender').head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 104    male        group C                some college      standard
# 934    male        group C          associate's degree      standard
# 34     male        group E                some college      standard
# 286    male        group E          associate's degree      standard
# 539    male        group A          associate's degree      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# ...

# %%
total_score = sp_df.filter(like='score').sum(axis=1)
sp_df['total score'] = total_score

# %%
sp_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sp_df = sp_df.assign(total_score_log=np.log(sp_df['total score']))

# %%
sp_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sp_df.drop(labels=['total score', 'total_score_log'], axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## Заполните пропуски

# %%
dota_df = pd.read_csv('dota_hero_stats.csv')
dota_df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota_df.groupby('legs', as_index=False).count()
# Out:
#    legs  Unnamed: 0  attack_type  id  localized_name  name  primary_attr  \
# 0     0          11           11  11              11    11            11
# 1     2          95           95  95              95    95            95
# 2     4           7            7   7               7     7             7
# 3     6           3            3   3               3     3             3
# 4     8           1            1   1               1     1             1
#
#    roles
# 0     11
# 1     95
# 2      7
# 3      3
# 4      1

# %% [markdown]
# ## Отметьте верные ячейки

# %%
acc_df = pd.read_csv('accountancy.csv')
acc_df.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
acc_df.groupby(['Type', 'Executor']).aggregate({'Salary': 'max'})
# Out:
#                Unnamed: 0  Salary
# Type Executor
# A    Loopa             46      58
#      Pupa              39     234
# B    Loopa             43     249
#      Pupa              41      77
# C    Loopa             47     249
#      Pupa              24      94
# D    Loopa             49     181
#      Pupa              31     194
# E    Loopa             42     220
#      Pupa              30     197
# F    Loopa             35     244
#      Pupa              48     195

# %% [markdown]
# ## Выберите один вариант из списка

# %%
df = pd.read_csv('dota_hero_stats.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
df.groupby(['attack_type', 'primary_attr']).count().id
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# Name: id, dtype: int64
