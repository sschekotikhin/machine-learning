# %%
import pandas as pd
import numpy as np

# %%
sp_df = pd.read_csv('StudentsPerformance.csv')
sp_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## Фильтрация

# %%
sp_df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
sp_df.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
sp_df.loc[sp_df.gender == 'female', ['gender']]
# Out:
#      gender
# 0    female
# 1    female
# 2    female
# 5    female
# 6    female
# ..      ...
# 993  female
# 995  female
# 997  female
# 998  female
# 999  female
#
# [518 rows x 1 columns]

# %%
mean_ws = sp_df['writing score'].mean()
print(f'Mean writing score: {mean_ws}')
sp_df.loc[sp_df['writing score'] < mean_ws]
# Out:
# Mean writing score: 68.054
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# ..      ...            ...                         ...           ...
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## Выберите все подходящие ответы из списка
# > При работе с pandas series для логического И нужно использовать & вместо уже знакомого and
#
# > Нужно указать приоритет операций, взяв условия в скобки [(condition) и (condition)]

# %%
query = (sp_df['writing score'] < mean_ws) & (sp_df.gender == 'male')
sp_df.loc[query]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# ..     ...            ...                         ...           ...
# 977   male        group C          associate's degree      standard
# 978   male        group D                 high school      standard
# 985   male        group A                 high school      standard
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %% [markdown]
# ## Введите численный ответ

# %%
sp_df.loc[sp_df.lunch == 'free/reduced'].shape[0] / sp_df.shape[0]
# Out:
# 0.355

# %% [markdown]
# ## Выберите все подходящие ответы из списка
# > студенты со стандартным ланчем имеют в среднем более хорошие оценки
#
# > дисперсия оценок студентов со стандартным ланчем меньше

# %%
sp_df.loc[sp_df.lunch == 'free/reduced'].describe().loc[['mean', 'std']]
# Out:
#       math score  reading score  writing score
# mean   58.921127      64.653521      63.022535
# std    15.159956      14.895339      15.433823

# %%
sp_df.loc[sp_df.lunch == 'standard'].describe().loc[['mean', 'std']]
# Out:
#       math score  reading score  writing score
# mean   70.034109      71.654264      70.823256
# std    13.653501      13.830602      14.339487

# %%
sp_df = sp_df.rename(columns={
    'parental level of education': 'parental_level_of_education',
    'race/ethnicity': 'race_ethnicity',
    'test preparation course': 'test_preparation_course',
    'math score': 'math_score',
    'reading score': 'reading_score',
    'writing score': 'writing_score'
})

# %%
sp_df.query('gender == "female" & writing_score > 75')
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 15   female        group C            some high school      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
avg_writing_score = sp_df.writing_score.mean()
sp_df.query('writing_score < @avg_writing_score') # через собаку можно обращатьс к переменным кода
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# ..      ...            ...                         ...           ...
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# ## Сопоставьте значения из двух списков
# ```python
# student_stats[student_stats['parental level of education'].isin(["bachelor's degree", "master's degree"])] # отберёт студентов, уровень образования родителей которых бакалавр или магистр
# student_stats[(student_stats['math score'] > 90) & (student_stats['reading score'] <=72)] # наблюдения, оценка за математику которых выше 90 и за чтение меньше либо равна 72
# student_stats[student_stats['test preparation course'] != 'completed'] # студенты, не прошедшие тест
# student_stats.query("lunch == 'standard'") # студенты со стандартным ланчем
# ```

# %%
student_stats = sp_df

# %%
student_stats[student_stats['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
student_stats[(student_stats['math_score'] > 90) & (student_stats['reading_score'] <=72)]
# Out:
# Empty DataFrame
# Columns: [gender, race_ethnicity, parental_level_of_education, lunch, test_preparation_course, math_score, reading_score, writing_score]
# Index: []

# %%
student_stats[student_stats['test_preparation_course'] != 'completed']
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
student_stats.query("lunch == 'standard'")
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# ...
