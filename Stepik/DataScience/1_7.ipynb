# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='math score', y='reading score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sns.lmplot(x='math score', y='reading score', data=df)

# %%
sns.lmplot(x='math score', y='reading score', data=df, hue='gender')

# %%
sns.lmplot(x='math score', y='reading score', data=df, hue='gender', fit_reg=False)

# %%
ax = sns.lmplot(x='math score', y='reading score', data=df, hue='gender', fit_reg=False)

ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

ax

# %% [markdown]
# ## Выберите все подходящие ответы из списка
# ```python
# df.plot(kind='line')
#
# sns.lineplot(x=df.index, y=df.income)
#
# plt.plot(df.index, df.income)
#
# df.income.plot()
#
# df.plot()
#
# sns.lineplot(data=df)
#
# df['income'].plot()
# ```

# %%
sns.lineplot(x=df.index, y=df['math score'])
# Out:
# <AxesSubplot:ylabel='math score'>

# %%
df['math score'].plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df['math score'])

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['math score'].plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Обработайте индивидуальный набор данных за отведённое время

# %%
dataset = pd.read_csv('dataset_209770_6.txt', sep=' ')

dataset
# Out:
#               x            y
# 0   1085.669935   605.192571
# 1   1206.627834  1401.025797
# 2   1103.465269   597.710712
# 3    110.806203   183.766901
# 4   1198.606404  1404.213773
# ..          ...          ...
# 95  1405.163436   821.406853
# 96   207.897770   897.827485
# 97   196.173710   910.575151
# 98   793.622978   504.416941
# 99   211.653959   908.824048
#
# [100 rows x 2 columns]

# %%
sns.lineplot(x=dataset.x, y=dataset.y)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x=dataset.x, y=dataset.y)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ## Выберите один вариант из списка
# 3 вариант

# %%
genome_df = pd.read_csv('genome_matrix.csv', index_col=0)

genome_df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(genome_df, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Введите численный ответ

# %%
dota_df = pd.read_csv('dota_hero_stats.csv')

dota_df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
hist = sns.histplot(data=dota_df.roles)

# %%
dota_df.roles.mode()
# Out:
# 0    ['Carry', 'Disabler', 'Initiator', 'Durable', ...
# 1                                  ['Carry', 'Escape']
# 2                     ['Support', 'Disabler', 'Nuker']
# 3           ['Support', 'Nuker', 'Disabler', 'Escape']
# 4                     ['Support', 'Nuker', 'Disabler']
# dtype: object

# %%
dota_df.roles.str.count(',') + 1
# Out:
# 0      3
# 1      4
# 2      4
# 3      5
# 4      4
#       ..
# 112    4
# 113    4
# 114    6
# 115    4
# 116    4
# Name: roles, Length: 117, dtype: int64

# %%
lenths = [len(r.split(',')) for r in dota_df.roles]
dota_df['lenths'] = lenths
dota_df['lenths'].describe()
# Out:
# count    117.000000
# mean       4.000000
# std        1.090713
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        6.000000
# Name: lenths, dtype: float64

# %% [markdown]
# ## Выберите все подходящие ответы из списка

# %%
iris_df = pd.read_csv('iris.csv')

iris_df
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
sns.scatterplot()
