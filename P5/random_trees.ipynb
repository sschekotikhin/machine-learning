# %% [markdown]
# ## RandomTreeClassifier

# %%
from sklearn import ensemble
from sklearn import datasets
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

import mglearn

import numpy as np

# %%
X, y = datasets.make_moons(n_samples=100, noise=.25, random_state=3)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    stratify=y,
    random_state=42
)

# %%
clf = ensemble.RandomForestClassifier(n_estimators=5, random_state=2)
clf.fit(X_train, y_train)

print(f'Train score: {clf.score(X_train, y_train)}')
print(f'Test score: {clf.score(X_test, y_test)}')
# Out:
# Train score: 0.96
# Test score: 0.92

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))
for index, (ax, clf) in enumerate(zip(axes.ravel(), clf.estimators_)):
    ax.set_title(f'Tree {index}')
    mglearn.plots.plot_tree_partition(X_train, y_train, clf, ax=ax)

mglearn.plots.plot_2d_separator(
    clf,
    X_train,
    fill=True,
    ax=axes[-1, -1],
    alpha=.4
)

axes[-1, -1].set_title('Random forest')
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)

# %%
cancer = datasets.load_breast_cancer()

X_train, X_test, y_train, y_test = train_test_split(
    cancer.data,
    cancer.target,
    random_state=0
)

# %%
clf = ensemble.RandomForestClassifier(n_estimators=100, random_state=0)
clf.fit(X_train, y_train)

print(f'Train score: {clf.score(X_train, y_train)}')
print(f'Test score: {clf.score(X_test, y_test)}')
# Out:
# Train score: 1.0
# Test score: 0.972027972027972

# %%
n_features = cancer.data.shape[1]

plt.barh(range(n_features), clf.feature_importances_, align='center')
plt.yticks(np.arange(n_features), cancer.feature_names)
plt.xlabel('Importance')
plt.ylabel('Feature')
# Out:
# Text(0, 0.5, 'Feature')

# %% [markdown]
# ## GradientBoostingClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data,
    cancer.target,
    random_state=0
)

# %%
clf = ensemble.GradientBoostingClassifier(random_state=0)
clf.fit(X_train, y_train)

print(f'Train score: {clf.score(X_train, y_train)}')
print(f'Test score: {clf.score(X_test, y_test)}')
# Out:
# Train score: 1.0
# Test score: 0.965034965034965

# %%
clf = ensemble.GradientBoostingClassifier(random_state=0, max_depth=1)
clf.fit(X_train, y_train)

print(f'Train score: {clf.score(X_train, y_train)}')
print(f'Test score: {clf.score(X_test, y_test)}')
# Out:
# Train score: 0.9906103286384976
# Test score: 0.972027972027972

# %%
clf = ensemble.GradientBoostingClassifier(random_state=0, learning_rate=0.01)
clf.fit(X_train, y_train)

print(f'Train score: {clf.score(X_train, y_train)}')
print(f'Test score: {clf.score(X_test, y_test)}')
# Out:
# Train score: 0.9882629107981221
# Test score: 0.965034965034965

# %%
clf = ensemble.GradientBoostingClassifier(random_state=0, max_depth=1)
clf.fit(X_train, y_train)

print(f'Train score: {clf.score(X_train, y_train)}')
print(f'Test score: {clf.score(X_test, y_test)}')

n_features = cancer.data.shape[1]

plt.barh(range(n_features), clf.feature_importances_, align='center')
plt.yticks(np.arange(n_features), cancer.feature_names)
plt.xlabel('Importance')
plt.ylabel('Feature')
# Out:
# Train score: 0.9906103286384976
# Test score: 0.972027972027972
# Text(0, 0.5, 'Feature')
